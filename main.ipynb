# %%
# Install the Google GenAI integration package for LangChain
# !pip install -q langchain-google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.3/475.3 kB 12.1 MB/s eta 0:00:00

# %%
import os
# --- Variable Updates ---
# IMPORTANT: Use your actual API Key here.
GOOGLE_API_KEY = "AIzaSyAH63yY-VadvtQzPSoLiyOmRSPPOmWhkYQ"
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

# We will now fix the model to the requested one
GEMINI_MODEL = 'gemini-2.5-flash'
models_list = [GEMINI_MODEL] # Now only contains our selected model
print(f"✅ LLM set to: {models_list[0]}")
# Out:
# ✅ LLM set to: gemini-2.5-flash

# %%
from itertools import product
from langchain_google_genai import ChatGoogleGenerativeAI
# Assuming prompts_data has been loaded from the input file

results = [] # This list will collect all our extended JSON objects

# How would you use itertools.product here to create the 'bomb' loop?

# for prompt_item, model_name, temp, max_tokens in ... :
#     # ... your code for the iteration here ...
